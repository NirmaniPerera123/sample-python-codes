# %% [markdown]
# # Question One

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
pd.pivot_table(tips, values = 'tip', index=['day'], columns='sex')
# Out:
# sex       Male    Female
# day
# Thur  2.980333  2.575625
# Fri   2.693000  2.781111
# Sat   3.083898  2.801786
# Sun   3.220345  3.367222

# %% [markdown]
# # Question Two

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.loc[(titanic['class']=='Third') & (titanic['alive']=='no') & (titanic['who']=='woman')]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 18          0       3  female  31.0      1      0  18.0000        S  Third
# 38          0       3  female  18.0      2      0  18.0000        S  Third
# 40          0       3  female  40.0      1      0   9.4750        S  Third
# 49          0       3  female  18.0      1      0  17.8000        S  Third
# 71          0       3  female  16.0      5      2  46.9000        S  Third
# 100         0       3  female  28.0      0      0   7.8958        S  Third
# 113         0       3  female  20.0      1      0   9.8250        S  Third
# 114         0       3  female  17.0      0      0  14.4583        C  Third
# 132         0       3  female  47.0      1      0  14.5000        S  Third
# 140         0       3  female   NaN      0      2  15.2458        C  Third
# 167         0       3  female  45.0      1      4  27.9000        S  Third
# ...

# %% [markdown]
# # Question Three

# %%
tips['percent'] = (tips['tip'] / tips['tip'].sum()) * 100
tips.sort_values("percent")
# Out:
#      total_bill    tip     sex smoker   day    time  size   percent
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1  0.136690
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2  0.136690
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2  0.136690
# 111        7.25   1.00  Female     No   Sat  Dinner     1  0.136690
# 0         16.99   1.01  Female     No   Sun  Dinner     2  0.138057
# ..          ...    ...     ...    ...   ...     ...   ...       ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6  0.915826
# 59        48.27   6.73    Male     No   Sat  Dinner     4  0.919927
# 23        39.42   7.58    Male     No   Sat  Dinner     4  1.036114
# 212       48.33   9.00    Male     No   Sat  Dinner     4  1.230214
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3  1.366905
#
# [244 rows x 8 columns]

# %% [markdown]
# # Question Four

# %%
mpg = sns.load_dataset("mpg")
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.groupby("origin")["weight"].mean()
# Out:
# origin
# europe    2423.300000
# japan     2221.227848
# usa       3361.931727
# Name: weight, dtype: float64

# %% [markdown]
# # Question Five

# %%
tips['food_bill'] = tips['total_bill'] - tips['tip']

# %%
tips.loc[(tips['sex']=='Male') & (tips['smoker']=='Yes'),('food_bill')].mean()
# Out:
# 19.233333333333338
